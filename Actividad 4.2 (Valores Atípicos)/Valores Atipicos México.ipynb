# %%
#importamos librerias

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#Cargar archivo .csv sin indice 

data=pd.read_csv("México_sin_nulos.csv")
data
# Out:
#        Unnamed: 0            id last_scraped  \
# 0               0  3.579700e+04   25/09/2024
# 1               1  4.461600e+04   26/09/2024
# 2               2  6.770300e+04   26/09/2024
# 3               3  7.064400e+04   25/09/2024
# 4               4  1.070780e+05   25/09/2024
# ...           ...           ...          ...
# 26577       26577  1.250000e+18   25/09/2024
# 26578       26578  1.250000e+18   25/09/2024
# 26579       26579  1.250000e+18   25/09/2024
# 26580       26580  1.250000e+18   25/09/2024
# 26581       26581  1.250000e+18   25/09/2024
#
#                                                    name  \
# 0                                           Villa Dante
# 1                                          Condesa Haus
# 2                     2 bedroom apt. deco bldg, Condesa
# 3      Beautiful light Studio Coyoacan- full equipped !
# 4                                    NEW  DESIGNER LOFT
# ...                                                 ...
# 26577    Charming 2-Bedroom Retreat in Lomas de Bezares
# 26578                     Suite King | District Polanco
# 26579                     Suite King | District Polanco
# 26580                    Suite Queen | District Polanco
# 26581                  Pretty, well centered, amenities
#
#                                              description  \
# 0      Dentro de Villa un estudio de arte con futon, ...
# 1      A new concept of hosting in mexico through a b...
# 2      Comfortably furnished, sunny, 2 bedroom apt., ...
# 3      COYOACAN designer studio quiet & safe! well eq...
# 4      Is the best ever place triple L <br />Location...
# ...                                                  ...
# 26577  Experience Mexico City in this delightful retr...
# 26578  This spacious room features a plush king-size ...
# 26579  Discover the essence of luxury in our king-siz...
# 26580  Welcome to your refuge in the heart of Polanco...
# 26581  Known as New Polanco, the Granada colony has p...
#
#                                    neighborhood_overview  \
# 0      Santa Fe Mall, Interloma Park and the Lion Des...
# 1                                        SIN INFORMACION
# 2                                        SIN INFORMACION
# 3      Coyoacan is a beautiful neighborhood famous fo...
# 4      Is located in the best area of Mexico City, Po...
# ...                                                  ...
# 26577  Welcome to Lomas de Bezares, a neighborhood kn...
# 26578                                    SIN INFORMACION
# 26579                                    SIN INFORMACION
# 26580                                    SIN INFORMACION
# 26581                                    SIN INFORMACION
#
#                                              picture_url   host_name  \
# 0      https://a0.muscache.com/pictures/f395ab78-1185...        Dici
# 1      https://a0.muscache.com/pictures/251410/ec75fe...    Fernando
# 2      https://a0.muscache.com/pictures/3281720/6f078...    Nicholas
# 3      https://a0.muscache.com/pictures/f397d2da-d045...      Trisha
# 4      https://a0.muscache.com/pictures/bd64f86d-4931...      Andrea
# ...                                                  ...         ...
# 26577  https://a0.muscache.com/pictures/prohost-api/H...     HostPal
# 26578  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26579  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26580  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26581  https://a0.muscache.com/pictures/hosting/Hosti...    Salvador
#
#        host_since                                         host_about  ...  \
# 0      28/06/2010  Master in visual arts, film photography & Mark...  ...
# 1      09/08/2010  Condesa Haus  offers independent  studios and ...  ...
# 2      04/01/2011  I am a journalist writing about food, (book an...  ...
# 3      24/08/2010  I am a mother, documentary film maker and phot...  ...
# 4      27/04/2011  I Leave in Mexico City... I am an Architect an...  ...
# ...           ...                                                ...  ...
# 26577  16/04/2016                                     SIN INFORMACIO  ...
# 26578  13/08/2024  We offer beautiful, comfortable spaces that wo...  ...
# 26579  13/08/2024  We offer beautiful, comfortable spaces that wo...  ...
# 26580  13/08/2024  We offer beautiful, comfortable spaces that wo...  ...
# 26581  22/05/2013                                                  .  ...
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     4.80                    4.80                       4.80
# 1                     4.58                    4.56                       4.70
# 2                     4.90                    4.81                       4.75
# 3                     4.91                    4.90                       4.96
# 4                     4.91                    5.00                       5.00
# ...                    ...                     ...                        ...
# 26577                 4.80                    4.80                       4.80
# 26578                 4.80                    4.80                       4.80
# 26579                 4.80                    4.80                       4.80
# 26580                 4.80                    4.80                       4.80
# 26581                 4.80                    4.80                       4.80
#
#       review_scores_checkin  review_scores_communication  \
# 0                      4.80                         4.80
# 1                      4.87                         4.78
# 2                      4.94                         4.92
# 3                      4.96                         4.98
# 4                      5.00                         4.73
# ...                     ...                          ...
# 26577                  4.80                         4.80
# 26578                  4.80                         4.80
# 26579                  4.80                         4.80
# 26580                  4.80                         4.80
# 26581                  4.80                         4.80
#
#        review_scores_location review_scores_value          license  \
# 0                        4.80                4.70  SIN INFORMACION
# 1                        4.98                4.48  SIN INFORMACION
# 2                        4.98                4.91  SIN INFORMACION
# 3                        4.96                4.92  SIN INFORMACION
# 4                        4.91                4.82  SIN INFORMACION
# ...                       ...                 ...              ...
# 26577                    4.80                4.70  SIN INFORMACION
# 26578                    4.80                4.70  SIN INFORMACION
# 26579                    4.80                4.70  SIN INFORMACION
# 26580                    4.80                4.70  SIN INFORMACION
# 26581                    4.80                4.70  SIN INFORMACION
#
#       instant_bookable reviews_per_month
# 0                    f              1.70
# 1                    f              0.41
# 2                    f              0.31
# 3                    f              0.83
# 4                    f              0.11
# ...                ...               ...
# 26577                t              1.70
# 26578                t              1.70
# 26579                t              1.70
# 26580                t              1.70
# 26581                t              1.70
#
# [26582 rows x 51 columns]

# %%
data= data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#                  id last_scraped  \
# 0      3.579700e+04   25/09/2024
# 1      4.461600e+04   26/09/2024
# 2      6.770300e+04   26/09/2024
# 3      7.064400e+04   25/09/2024
# 4      1.070780e+05   25/09/2024
# ...             ...          ...
# 26577  1.250000e+18   25/09/2024
# 26578  1.250000e+18   25/09/2024
# 26579  1.250000e+18   25/09/2024
# 26580  1.250000e+18   25/09/2024
# 26581  1.250000e+18   25/09/2024
#
#                                                    name  \
# 0                                           Villa Dante
# 1                                          Condesa Haus
# 2                     2 bedroom apt. deco bldg, Condesa
# 3      Beautiful light Studio Coyoacan- full equipped !
# 4                                    NEW  DESIGNER LOFT
# ...                                                 ...
# 26577    Charming 2-Bedroom Retreat in Lomas de Bezares
# 26578                     Suite King | District Polanco
# 26579                     Suite King | District Polanco
# 26580                    Suite Queen | District Polanco
# 26581                  Pretty, well centered, amenities
#
#                                              description  \
# 0      Dentro de Villa un estudio de arte con futon, ...
# 1      A new concept of hosting in mexico through a b...
# 2      Comfortably furnished, sunny, 2 bedroom apt., ...
# 3      COYOACAN designer studio quiet & safe! well eq...
# 4      Is the best ever place triple L <br />Location...
# ...                                                  ...
# 26577  Experience Mexico City in this delightful retr...
# 26578  This spacious room features a plush king-size ...
# 26579  Discover the essence of luxury in our king-siz...
# 26580  Welcome to your refuge in the heart of Polanco...
# 26581  Known as New Polanco, the Granada colony has p...
#
#                                    neighborhood_overview  \
# 0      Santa Fe Mall, Interloma Park and the Lion Des...
# 1                                        SIN INFORMACION
# 2                                        SIN INFORMACION
# 3      Coyoacan is a beautiful neighborhood famous fo...
# 4      Is located in the best area of Mexico City, Po...
# ...                                                  ...
# 26577  Welcome to Lomas de Bezares, a neighborhood kn...
# 26578                                    SIN INFORMACION
# 26579                                    SIN INFORMACION
# 26580                                    SIN INFORMACION
# 26581                                    SIN INFORMACION
#
#                                              picture_url   host_name  \
# 0      https://a0.muscache.com/pictures/f395ab78-1185...        Dici
# 1      https://a0.muscache.com/pictures/251410/ec75fe...    Fernando
# 2      https://a0.muscache.com/pictures/3281720/6f078...    Nicholas
# 3      https://a0.muscache.com/pictures/f397d2da-d045...      Trisha
# 4      https://a0.muscache.com/pictures/bd64f86d-4931...      Andrea
# ...                                                  ...         ...
# 26577  https://a0.muscache.com/pictures/prohost-api/H...     HostPal
# 26578  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26579  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26580  https://a0.muscache.com/pictures/miso/Hosting-...  Luis Angel
# 26581  https://a0.muscache.com/pictures/hosting/Hosti...    Salvador
#
#        host_since                                         host_about  \
# 0      28/06/2010  Master in visual arts, film photography & Mark...
# 1      09/08/2010  Condesa Haus  offers independent  studios and ...
# 2      04/01/2011  I am a journalist writing about food, (book an...
# 3      24/08/2010  I am a mother, documentary film maker and phot...
# 4      27/04/2011  I Leave in Mexico City... I am an Architect an...
# ...           ...                                                ...
# 26577  16/04/2016                                     SIN INFORMACIO
# 26578  13/08/2024  We offer beautiful, comfortable spaces that wo...
# 26579  13/08/2024  We offer beautiful, comfortable spaces that wo...
# 26580  13/08/2024  We offer beautiful, comfortable spaces that wo...
# 26581  22/05/2013                                                  .
#
#        host_response_time  ...  review_scores_rating  review_scores_accuracy  \
# 0      a few days or more  ...                  4.80                    4.80
# 1          within an hour  ...                  4.58                    4.56
# 2          within an hour  ...                  4.90                    4.81
# 3      within a few hours  ...                  4.91                    4.90
# 4          within an hour  ...                  4.91                    5.00
# ...                   ...  ...                   ...                     ...
# 26577      within an hour  ...                  4.80                    4.80
# 26578      within an hour  ...                  4.80                    4.80
# 26579      within an hour  ...                  4.80                    4.80
# 26580      within an hour  ...                  4.80                    4.80
# 26581      within an hour  ...                  4.80                    4.80
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          4.80                   4.80
# 1                          4.70                   4.87
# 2                          4.75                   4.94
# 3                          4.96                   4.96
# 4                          5.00                   5.00
# ...                         ...                    ...
# 26577                      4.80                   4.80
# 26578                      4.80                   4.80
# 26579                      4.80                   4.80
# 26580                      4.80                   4.80
# 26581                      4.80                   4.80
#
#        review_scores_communication review_scores_location review_scores_value  \
# 0                             4.80                   4.80                4.70
# 1                             4.78                   4.98                4.48
# 2                             4.92                   4.98                4.91
# 3                             4.98                   4.96                4.92
# 4                             4.73                   4.91                4.82
# ...                            ...                    ...                 ...
# 26577                         4.80                   4.80                4.70
# 26578                         4.80                   4.80                4.70
# 26579                         4.80                   4.80                4.70
# 26580                         4.80                   4.80                4.70
# 26581                         4.80                   4.80                4.70
#
#                license instant_bookable reviews_per_month
# 0      SIN INFORMACION                f              1.70
# 1      SIN INFORMACION                f              0.41
# 2      SIN INFORMACION                f              0.31
# 3      SIN INFORMACION                f              0.83
# 4      SIN INFORMACION                f              0.11
# ...                ...              ...               ...
# 26577  SIN INFORMACION                t              1.70
# 26578  SIN INFORMACION                t              1.70
# 26579  SIN INFORMACION                t              1.70
# 26580  SIN INFORMACION                t              1.70
# 26581  SIN INFORMACION                t              1.70
#
# [26582 rows x 50 columns]

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# id                             0
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms                      0
# bathrooms_text                 0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# calendar_updated               0
# has_availability               0
# availability_30                0
# availability_60                0
# availability_365               0
# calendar_last_scraped          0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# last_review                    0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# license                        0
# instant_bookable               0
# reviews_per_month              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           26582 non-null  float64
#  1   last_scraped                 26582 non-null  object
#  2   name                         26582 non-null  object
#  3   description                  26582 non-null  object
#  4   neighborhood_overview        26582 non-null  object
#  5   picture_url                  26582 non-null  object
#  6   host_name                    26582 non-null  object
#  7   host_since                   26582 non-null  object
#  8   host_about                   26582 non-null  object
#  9   host_response_time           26582 non-null  object
#  10  host_response_rate           26582 non-null  float64
#  11  host_acceptance_rate         26582 non-null  float64
#  12  host_is_superhost            26582 non-null  object
#  13  host_listings_count          26582 non-null  int64
#  14  host_total_listings_count    26582 non-null  int64
#  15  host_verifications           26582 non-null  object
#  16  host_has_profile_pic         26582 non-null  object
#  17  host_identity_verified       26582 non-null  object
#  18  neighbourhood                26582 non-null  object
#  19  property_type                26582 non-null  object
#  20  room_type                    26582 non-null  object
#  21  accommodates                 26582 non-null  int64
#  22  bathrooms                    26582 non-null  float64
#  23  bathrooms_text               26582 non-null  object
#  24  bedrooms                     26582 non-null  float64
#  25  beds                         26582 non-null  float64
#  26  amenities                    26582 non-null  object
#  27  price                        26582 non-null  float64
#  28  minimum_nights               26582 non-null  int64
#  29  maximum_nights               26582 non-null  int64
#  30  calendar_updated             26582 non-null  object
#  31  has_availability             26582 non-null  object
#  32  availability_30              26582 non-null  int64
#  33  availability_60              26582 non-null  int64
#  34  availability_365             26582 non-null  int64
#  35  calendar_last_scraped        26582 non-null  object
#  36  number_of_reviews            26582 non-null  int64
#  37  number_of_reviews_ltm        26582 non-null  int64
#  38  number_of_reviews_l30d       26582 non-null  int64
#  39  last_review                  26582 non-null  object
#  40  review_scores_rating         26582 non-null  float64
#  41  review_scores_accuracy       26582 non-null  float64
#  42  review_scores_cleanliness    26582 non-null  float64
#  43  review_scores_checkin        26582 non-null  float64
#  44  review_scores_communication  26582 non-null  float64
#  45  review_scores_location       26582 non-null  float64
#  46  review_scores_value          26582 non-null  float64
#  47  license                      26582 non-null  object
#  48  instant_bookable             26582 non-null  object
#  49  reviews_per_month            26582 non-null  float64
# dtypes: float64(15), int64(11), object(24)
# memory usage: 10.1+ MB

# %%
cuantitativos= data.iloc[:,[0,10,11,13,14,21,22,24,25,27,28,29,32,33,34,36,37,38,40,41,42,43,44,45,46,49]]
cualitativos=data.iloc[:,[1,2,3,4,5,6,7,8,9,12,15,16,17,18,19,20,23,26,30,31,35,39,47,48]]

# %%
cualitativos

# %%
cuantitativos

# %%
#Realizar diagrama de caja o bigote de cada columna del datframe 

fig = plt.figure(figsize=(15, 8))
cuantitativos.plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["id"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["host_response_rate"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["host_acceptance_rate"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["host_listings_count"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["host_total_listings_count"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["accommodates"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["bathrooms"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["bedrooms"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["beds"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["price"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["minimum_nights"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["maximum_nights"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["availability_30"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["availability_60"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["availability_365"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["number_of_reviews"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["number_of_reviews_ltm"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["number_of_reviews_l30d"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["review_scores_rating"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["review_scores_accuracy"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["review_scores_cleanliness"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["review_scores_checkin"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["review_scores_communication"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["review_scores_location"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["review_scores_value"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
cuantitativos["reviews_per_month"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show()

# %% [markdown]
# **DESVIACIÓN ESTANDAR**

# %%
#Encuentro los valores extremos 

y=cuantitativos
Limite_Superior=y.mean() +3*y.std()
Limite_Inferior=y.mean() -3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido id                             1.997600e+18
# host_response_rate             1.346129e+00
# host_acceptance_rate           1.382464e+00
# host_listings_count            3.295566e+02
# host_total_listings_count      6.148874e+02
# accommodates                   1.043010e+01
# bathrooms                      4.735292e+00
# bedrooms                       5.386100e+00
# beds                           7.095158e+00
# price                          1.583066e+04
# minimum_nights                 8.183006e+01
# maximum_nights                 1.793887e+03
# availability_30                4.852387e+01
# availability_60                9.733159e+01
# availability_365               6.026093e+02
# number_of_reviews              2.711536e+02
# number_of_reviews_ltm          7.505979e+01
# number_of_reviews_l30d         6.823979e+00
# review_scores_rating           5.790227e+00
# review_scores_accuracy         5.771173e+00
# review_scores_cleanliness      5.775990e+00
# review_scores_checkin          5.706628e+00
# review_scores_communication    5.807539e+00
# review_scores_location         5.650290e+00
# review_scores_value            5.772903e+00
# reviews_per_month              7.185098e+00
# dtype: float64
# Limite inferior permitido id                            -9.359381e+17
# host_response_rate             5.862646e-01
# host_acceptance_rate           4.980502e-01
# host_listings_count           -2.755585e+02
# host_total_listings_count     -5.394181e+02
# accommodates                  -3.750922e+00
# bathrooms                     -2.109041e+00
# bedrooms                      -2.349082e+00
# beds                          -3.596700e+00
# price                         -1.280738e+04
# minimum_nights                -7.214674e+01
# maximum_nights                -7.417401e+02
# availability_30               -1.916001e+01
# availability_60               -3.257574e+01
# availability_365              -1.615437e+02
# number_of_reviews             -1.802145e+02
# number_of_reviews_ltm         -4.692858e+01
# number_of_reviews_l30d        -4.659657e+00
# review_scores_rating           3.735803e+00
# review_scores_accuracy         3.818267e+00
# review_scores_cleanliness      3.758262e+00
# review_scores_checkin          3.968180e+00
# review_scores_communication    3.843969e+00
# review_scores_location         4.029021e+00
# review_scores_value            3.670681e+00
# reviews_per_month             -3.712928e+00
# dtype: float64

# %%
#Los outliers se convierten en valores nulos
data2= cuantitativos[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data2
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.579700e+04                1.00                  1.00
# 1      4.461600e+04                1.00                  0.93
# 2      6.770300e+04                0.71                  0.57
# 3      7.064400e+04                1.00                  1.00
# 4      1.070780e+05                1.00                  1.00
# ...             ...                 ...                   ...
# 26577  1.250000e+18                1.00                  1.00
# 26578  1.250000e+18                1.00                  1.00
# 26579  1.250000e+18                1.00                  1.00
# 26580  1.250000e+18                1.00                  1.00
# 26581  1.250000e+18                1.00                  1.00
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      1.0                        1.0           2.0
# 1                     12.0                       13.0           NaN
# 2                      3.0                        4.0           4.0
# 3                      3.0                        4.0           2.0
# 4                      5.0                        7.0           2.0
# ...                    ...                        ...           ...
# 26577                167.0                      279.0           4.0
# 26578                 16.0                       16.0           2.0
# 26579                 16.0                       16.0           2.0
# 26580                 16.0                       16.0           2.0
# 26581                  4.0                        6.0           2.0
#
#        bathrooms  bedrooms  beds   price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0  3865.0  ...                    0.0
# 1            0.0       5.0   0.0  1511.6  ...                    0.0
# 2            1.0       2.0   2.0  2029.0  ...                    4.0
# 3            1.0       1.0   1.0  1140.0  ...                    7.0
# 4            1.5       1.0   1.0  3633.0  ...                    0.0
# ...          ...       ...   ...     ...  ...                    ...
# 26577        1.0       2.0   2.0   488.0  ...                    0.0
# 26578        1.0       1.0   1.0  2800.0  ...                    0.0
# 26579        1.0       1.0   1.0  2700.0  ...                    0.0
# 26580        1.0       1.0   1.0  2600.0  ...                    0.0
# 26581        1.0       1.0   1.0  1353.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.80                    4.80
# 1                         0.0                  4.58                    4.56
# 2                         0.0                  4.90                    4.81
# 3                         2.0                  4.91                    4.90
# 4                         0.0                  4.91                    5.00
# ...                       ...                   ...                     ...
# 26577                     0.0                  4.80                    4.80
# 26578                     0.0                  4.80                    4.80
# 26579                     0.0                  4.80                    4.80
# 26580                     0.0                  4.80                    4.80
# 26581                     0.0                  4.80                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.80                   4.80
# 1                           4.70                   4.87
# 2                           4.75                   4.94
# 3                           4.96                   4.96
# 4                           5.00                   5.00
# ...                          ...                    ...
# 26577                       4.80                   4.80
# 26578                       4.80                   4.80
# 26579                       4.80                   4.80
# 26580                       4.80                   4.80
# 26581                       4.80                   4.80
#
#        review_scores_communication  review_scores_location  \
# 0                             4.80                    4.80
# 1                             4.78                    4.98
# 2                             4.92                    4.98
# 3                             4.98                    4.96
# 4                             4.73                    4.91
# ...                            ...                     ...
# 26577                         4.80                    4.80
# 26578                         4.80                    4.80
# 26579                         4.80                    4.80
# 26580                         4.80                    4.80
# 26581                         4.80                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.70               1.70
# 1                     4.48               0.41
# 2                     4.91               0.31
# 3                     4.92               0.83
# 4                     4.82               0.11
# ...                    ...                ...
# 26577                 4.70               1.70
# 26578                 4.70               1.70
# 26579                 4.70               1.70
# 26580                 4.70               1.70
# 26581                 4.70               1.70
#
# [26582 rows x 26 columns]

# %%
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# id                               0
# host_response_rate             766
# host_acceptance_rate           837
# host_listings_count            304
# host_total_listings_count      380
# accommodates                   526
# bathrooms                      309
# bedrooms                       286
# beds                           334
# price                           94
# minimum_nights                 190
# maximum_nights                   1
# availability_30                  0
# availability_60                  0
# availability_365                 0
# number_of_reviews              608
# number_of_reviews_ltm          432
# number_of_reviews_l30d         511
# review_scores_rating           408
# review_scores_accuracy         402
# review_scores_cleanliness      436
# review_scores_checkin          310
# review_scores_communication    435
# review_scores_location         518
# review_scores_value            467
# reviews_per_month              396
# dtype: int64

# %%
#Reemplazamos valores atipicos (nulos) del dataframe con "mean"
#Realizamos ua copia del dataframe 

data_clean=data2.copy()
data_clean=data_clean.fillna(round(data2.mean(),1))
data_clean
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.579700e+04                1.00                  1.00
# 1      4.461600e+04                1.00                  0.93
# 2      6.770300e+04                0.71                  0.57
# 3      7.064400e+04                1.00                  1.00
# 4      1.070780e+05                1.00                  1.00
# ...             ...                 ...                   ...
# 26577  1.250000e+18                1.00                  1.00
# 26578  1.250000e+18                1.00                  1.00
# 26579  1.250000e+18                1.00                  1.00
# 26580  1.250000e+18                1.00                  1.00
# 26581  1.250000e+18                1.00                  1.00
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      1.0                        1.0           2.0
# 1                     12.0                       13.0           3.1
# 2                      3.0                        4.0           4.0
# 3                      3.0                        4.0           2.0
# 4                      5.0                        7.0           2.0
# ...                    ...                        ...           ...
# 26577                167.0                      279.0           4.0
# 26578                 16.0                       16.0           2.0
# 26579                 16.0                       16.0           2.0
# 26580                 16.0                       16.0           2.0
# 26581                  4.0                        6.0           2.0
#
#        bathrooms  bedrooms  beds   price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0  3865.0  ...                    0.0
# 1            0.0       5.0   0.0  1511.6  ...                    0.0
# 2            1.0       2.0   2.0  2029.0  ...                    4.0
# 3            1.0       1.0   1.0  1140.0  ...                    7.0
# 4            1.5       1.0   1.0  3633.0  ...                    0.0
# ...          ...       ...   ...     ...  ...                    ...
# 26577        1.0       2.0   2.0   488.0  ...                    0.0
# 26578        1.0       1.0   1.0  2800.0  ...                    0.0
# 26579        1.0       1.0   1.0  2700.0  ...                    0.0
# 26580        1.0       1.0   1.0  2600.0  ...                    0.0
# 26581        1.0       1.0   1.0  1353.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.80                    4.80
# 1                         0.0                  4.58                    4.56
# 2                         0.0                  4.90                    4.81
# 3                         2.0                  4.91                    4.90
# 4                         0.0                  4.91                    5.00
# ...                       ...                   ...                     ...
# 26577                     0.0                  4.80                    4.80
# 26578                     0.0                  4.80                    4.80
# 26579                     0.0                  4.80                    4.80
# 26580                     0.0                  4.80                    4.80
# 26581                     0.0                  4.80                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.80                   4.80
# 1                           4.70                   4.87
# 2                           4.75                   4.94
# 3                           4.96                   4.96
# 4                           5.00                   5.00
# ...                          ...                    ...
# 26577                       4.80                   4.80
# 26578                       4.80                   4.80
# 26579                       4.80                   4.80
# 26580                       4.80                   4.80
# 26581                       4.80                   4.80
#
#        review_scores_communication  review_scores_location  \
# 0                             4.80                    4.80
# 1                             4.78                    4.98
# 2                             4.92                    4.98
# 3                             4.98                    4.96
# 4                             4.73                    4.91
# ...                            ...                     ...
# 26577                         4.80                    4.80
# 26578                         4.80                    4.80
# 26579                         4.80                    4.80
# 26580                         4.80                    4.80
# 26581                         4.80                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.70               1.70
# 1                     4.48               0.41
# 2                     4.91               0.31
# 3                     4.92               0.83
# 4                     4.82               0.11
# ...                    ...                ...
# 26577                 4.70               1.70
# 26578                 4.70               1.70
# 26579                 4.70               1.70
# 26580                 4.70               1.70
# 26581                 4.70               1.70
#
# [26582 rows x 26 columns]

# %%
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %% [markdown]
# **CUARTILES**

# %%
#Metodo aplicando Cuartiles, encuentro cuartiles 0.25 y 0.75

y=cuantitativos

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superiro permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superiro permitido id                             2.467500e+18
# host_response_rate             1.000000e+00
# host_acceptance_rate           1.045000e+00
# host_listings_count            3.350000e+01
# host_total_listings_count      3.950000e+01
# accommodates                   7.000000e+00
# bathrooms                      3.500000e+00
# bedrooms                       3.500000e+00
# beds                           3.500000e+00
# price                          2.795000e+03
# minimum_nights                 3.500000e+00
# maximum_nights                 2.542500e+03
# availability_30                6.350000e+01
# availability_60                1.130000e+02
# availability_365               7.105000e+02
# number_of_reviews              1.355000e+02
# number_of_reviews_ltm          5.250000e+01
# number_of_reviews_l30d         5.000000e+00
# review_scores_rating           5.255000e+00
# review_scores_accuracy         5.230000e+00
# review_scores_cleanliness      5.265000e+00
# review_scores_checkin          5.300000e+00
# review_scores_communication    5.300000e+00
# review_scores_location         5.300000e+00
# review_scores_value            5.215000e+00
# reviews_per_month              4.720000e+00
# dtype: float64
# Limite inferior permitido id                            -1.480500e+18
# host_response_rate             1.000000e+00
# host_acceptance_rate           9.250000e-01
# host_listings_count           -1.850000e+01
# host_total_listings_count     -2.050000e+01
# accommodates                  -1.000000e+00
# bathrooms                     -5.000000e-01
# bedrooms                      -5.000000e-01
# beds                          -5.000000e-01
# price                         -6.274000e+02
# minimum_nights                -5.000000e-01
# maximum_nights                -1.237500e+03
# availability_30               -3.650000e+01
# availability_60               -4.700000e+01
# availability_365              -2.775000e+02
# number_of_reviews             -7.650000e+01
# number_of_reviews_ltm         -3.150000e+01
# number_of_reviews_l30d        -3.000000e+00
# review_scores_rating           4.415000e+00
# review_scores_accuracy         4.510000e+00
# review_scores_cleanliness      4.425000e+00
# review_scores_checkin          4.500000e+00
# review_scores_communication    4.500000e+00
# review_scores_location         4.500000e+00
# review_scores_value            4.375000e+00
# reviews_per_month             -2.000000e+00
# dtype: float64

# %%
data2_iqr = cuantitativos[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data2_iqr
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.579700e+04                 1.0                  1.00
# 1      4.461600e+04                 1.0                  0.93
# 2      6.770300e+04                 NaN                   NaN
# 3      7.064400e+04                 1.0                  1.00
# 4      1.070780e+05                 1.0                  1.00
# ...             ...                 ...                   ...
# 26577  1.250000e+18                 1.0                  1.00
# 26578  1.250000e+18                 1.0                  1.00
# 26579  1.250000e+18                 1.0                  1.00
# 26580  1.250000e+18                 1.0                  1.00
# 26581  1.250000e+18                 1.0                  1.00
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      1.0                        1.0           2.0
# 1                     12.0                       13.0           NaN
# 2                      3.0                        4.0           4.0
# 3                      3.0                        4.0           2.0
# 4                      5.0                        7.0           2.0
# ...                    ...                        ...           ...
# 26577                  NaN                        NaN           4.0
# 26578                 16.0                       16.0           2.0
# 26579                 16.0                       16.0           2.0
# 26580                 16.0                       16.0           2.0
# 26581                  4.0                        6.0           2.0
#
#        bathrooms  bedrooms  beds   price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0     NaN  ...                    0.0
# 1            0.0       NaN   0.0  1511.6  ...                    0.0
# 2            1.0       2.0   2.0  2029.0  ...                    4.0
# 3            1.0       1.0   1.0  1140.0  ...                    7.0
# 4            1.5       1.0   1.0     NaN  ...                    0.0
# ...          ...       ...   ...     ...  ...                    ...
# 26577        1.0       2.0   2.0   488.0  ...                    0.0
# 26578        1.0       1.0   1.0     NaN  ...                    0.0
# 26579        1.0       1.0   1.0  2700.0  ...                    0.0
# 26580        1.0       1.0   1.0  2600.0  ...                    0.0
# 26581        1.0       1.0   1.0  1353.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.80                    4.80
# 1                         0.0                  4.58                    4.56
# 2                         0.0                  4.90                    4.81
# 3                         2.0                  4.91                    4.90
# 4                         0.0                  4.91                    5.00
# ...                       ...                   ...                     ...
# 26577                     0.0                  4.80                    4.80
# 26578                     0.0                  4.80                    4.80
# 26579                     0.0                  4.80                    4.80
# 26580                     0.0                  4.80                    4.80
# 26581                     0.0                  4.80                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.80                   4.80
# 1                           4.70                   4.87
# 2                           4.75                   4.94
# 3                           4.96                   4.96
# 4                           5.00                   5.00
# ...                          ...                    ...
# 26577                       4.80                   4.80
# 26578                       4.80                   4.80
# 26579                       4.80                   4.80
# 26580                       4.80                   4.80
# 26581                       4.80                   4.80
#
#        review_scores_communication  review_scores_location  \
# 0                             4.80                    4.80
# 1                             4.78                    4.98
# 2                             4.92                    4.98
# 3                             4.98                    4.96
# 4                             4.73                    4.91
# ...                            ...                     ...
# 26577                         4.80                    4.80
# 26578                         4.80                    4.80
# 26579                         4.80                    4.80
# 26580                         4.80                    4.80
# 26581                         4.80                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.70               1.70
# 1                     4.48               0.41
# 2                     4.91               0.31
# 3                     4.92               0.83
# 4                     4.82               0.11
# ...                    ...                ...
# 26577                 4.70               1.70
# 26578                 4.70               1.70
# 26579                 4.70               1.70
# 26580                 4.70               1.70
# 26581                 4.70               1.70
#
# [26582 rows x 26 columns]

# %%
valores_nulos=data2_iqr.isnull().sum()
valores_nulos
# Out:
# id                                0
# host_response_rate             4810
# host_acceptance_rate           4510
# host_listings_count            3567
# host_total_listings_count      3764
# accommodates                   1352
# bathrooms                       644
# bedrooms                        858
# beds                           2447
# price                          2083
# minimum_nights                 3584
# maximum_nights                    0
# availability_30                   0
# availability_60                   0
# availability_365                  0
# number_of_reviews              2328
# number_of_reviews_ltm          1318
# number_of_reviews_l30d          813
# review_scores_rating           1868
# review_scores_accuracy         2198
# review_scores_cleanliness      1987
# review_scores_checkin          1184
# review_scores_communication    1458
# review_scores_location         1216
# review_scores_value            1944
# reviews_per_month              1433
# dtype: int64

# %%
#Reemplazamos valores atipicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe 

data3_iqr=data2_iqr.copy()
data3_iqr=data3_iqr.fillna(round(data2_iqr.mean(),1))
data3_iqr
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.579700e+04                 1.0                  1.00
# 1      4.461600e+04                 1.0                  0.93
# 2      6.770300e+04                 1.0                  1.00
# 3      7.064400e+04                 1.0                  1.00
# 4      1.070780e+05                 1.0                  1.00
# ...             ...                 ...                   ...
# 26577  1.250000e+18                 1.0                  1.00
# 26578  1.250000e+18                 1.0                  1.00
# 26579  1.250000e+18                 1.0                  1.00
# 26580  1.250000e+18                 1.0                  1.00
# 26581  1.250000e+18                 1.0                  1.00
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      1.0                        1.0           2.0
# 1                     12.0                       13.0           2.9
# 2                      3.0                        4.0           4.0
# 3                      3.0                        4.0           2.0
# 4                      5.0                        7.0           2.0
# ...                    ...                        ...           ...
# 26577                  6.2                        7.3           4.0
# 26578                 16.0                       16.0           2.0
# 26579                 16.0                       16.0           2.0
# 26580                 16.0                       16.0           2.0
# 26581                  4.0                        6.0           2.0
#
#        bathrooms  bedrooms  beds   price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0  1093.1  ...                    0.0
# 1            0.0       1.4   0.0  1511.6  ...                    0.0
# 2            1.0       2.0   2.0  2029.0  ...                    4.0
# 3            1.0       1.0   1.0  1140.0  ...                    7.0
# 4            1.5       1.0   1.0  1093.1  ...                    0.0
# ...          ...       ...   ...     ...  ...                    ...
# 26577        1.0       2.0   2.0   488.0  ...                    0.0
# 26578        1.0       1.0   1.0  1093.1  ...                    0.0
# 26579        1.0       1.0   1.0  2700.0  ...                    0.0
# 26580        1.0       1.0   1.0  2600.0  ...                    0.0
# 26581        1.0       1.0   1.0  1353.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.80                    4.80
# 1                         0.0                  4.58                    4.56
# 2                         0.0                  4.90                    4.81
# 3                         2.0                  4.91                    4.90
# 4                         0.0                  4.91                    5.00
# ...                       ...                   ...                     ...
# 26577                     0.0                  4.80                    4.80
# 26578                     0.0                  4.80                    4.80
# 26579                     0.0                  4.80                    4.80
# 26580                     0.0                  4.80                    4.80
# 26581                     0.0                  4.80                    4.80
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.80                   4.80
# 1                           4.70                   4.87
# 2                           4.75                   4.94
# 3                           4.96                   4.96
# 4                           5.00                   5.00
# ...                          ...                    ...
# 26577                       4.80                   4.80
# 26578                       4.80                   4.80
# 26579                       4.80                   4.80
# 26580                       4.80                   4.80
# 26581                       4.80                   4.80
#
#        review_scores_communication  review_scores_location  \
# 0                             4.80                    4.80
# 1                             4.78                    4.98
# 2                             4.92                    4.98
# 3                             4.98                    4.96
# 4                             4.73                    4.91
# ...                            ...                     ...
# 26577                         4.80                    4.80
# 26578                         4.80                    4.80
# 26579                         4.80                    4.80
# 26580                         4.80                    4.80
# 26581                         4.80                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.70               1.70
# 1                     4.48               0.41
# 2                     4.91               0.31
# 3                     4.92               0.83
# 4                     4.82               0.11
# ...                    ...                ...
# 26577                 4.70               1.70
# 26578                 4.70               1.70
# 26579                 4.70               1.70
# 26580                 4.70               1.70
# 26581                 4.70               1.70
#
# [26582 rows x 26 columns]

# %%
#Unimos el dataframe cuantitativo limpio con el dataframe cualitativo 

Datos_limpios = pd.concat([data3_iqr, cualitativos], axis=1)
Datos_limpios
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.579700e+04                 1.0                  1.00
# 1      4.461600e+04                 1.0                  0.93
# 2      6.770300e+04                 1.0                  1.00
# 3      7.064400e+04                 1.0                  1.00
# 4      1.070780e+05                 1.0                  1.00
# ...             ...                 ...                   ...
# 26577  1.250000e+18                 1.0                  1.00
# 26578  1.250000e+18                 1.0                  1.00
# 26579  1.250000e+18                 1.0                  1.00
# 26580  1.250000e+18                 1.0                  1.00
# 26581  1.250000e+18                 1.0                  1.00
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      1.0                        1.0           2.0
# 1                     12.0                       13.0           2.9
# 2                      3.0                        4.0           4.0
# 3                      3.0                        4.0           2.0
# 4                      5.0                        7.0           2.0
# ...                    ...                        ...           ...
# 26577                  6.2                        7.3           4.0
# 26578                 16.0                       16.0           2.0
# 26579                 16.0                       16.0           2.0
# 26580                 16.0                       16.0           2.0
# 26581                  4.0                        6.0           2.0
#
#        bathrooms  bedrooms  beds   price  ...               property_type  \
# 0            1.0       1.0   1.0  1093.1  ...                Entire villa
# 1            0.0       1.4   0.0  1511.6  ...                 Entire home
# 2            1.0       2.0   2.0  2029.0  ...          Entire rental unit
# 3            1.0       1.0   1.0  1140.0  ...          Entire rental unit
# 4            1.5       1.0   1.0  1093.1  ...                 Entire loft
# ...          ...       ...   ...     ...  ...                         ...
# 26577        1.0       2.0   2.0   488.0  ...  Private room in guesthouse
# 26578        1.0       1.0   1.0  1093.1  ...               Room in hotel
# 26579        1.0       1.0   1.0  2700.0  ...               Room in hotel
# 26580        1.0       1.0   1.0  2600.0  ...               Room in hotel
# 26581        1.0       1.0   1.0  1353.0  ...          Entire rental unit
#
#              room_type  bathrooms_text  \
# 0      Entire home/apt          1 bath
# 1      Entire home/apt       5.5 baths
# 2      Entire home/apt          1 bath
# 3      Entire home/apt          1 bath
# 4      Entire home/apt       1.5 baths
# ...                ...             ...
# 26577     Private room  1 private bath
# 26578     Private room  1 private bath
# 26579     Private room  1 private bath
# 26580     Private room  1 private bath
# 26581  Entire home/apt          1 bath
#
#                                                amenities  calendar_updated  \
# 0      ["Free parking on premises", "Washer", "Wifi",...   SIN INFORMACION
# 1      ["Iron", "Washer", "Wifi", "Host greets you", ...   SIN INFORMACION
# 2      ["Iron", "Wifi", "Bathtub", "Refrigerator", "D...   SIN INFORMACION
# 3      ["Iron", "Washer", "Outdoor furniture", "Wifi"...   SIN INFORMACION
# 4      ["Iron", "Washer", "Outdoor furniture", "Wifi"...   SIN INFORMACION
# ...                                                  ...               ...
# 26577  ["Wifi", "Heating", "Freezer", "Cleaning avail...   SIN INFORMACION
# 26578  ["Shared patio or balcony", "Iron", "Outdoor f...   SIN INFORMACION
# 26579  ["Shared patio or balcony", "Iron", "Outdoor f...   SIN INFORMACION
# 26580  ["Shared patio or balcony", "Iron", "Outdoor f...   SIN INFORMACION
# 26581  ["Free parking on premises", "Washer", "TV", "...   SIN INFORMACION
#
#        has_availability  calendar_last_scraped      last_review  \
# 0                     t             25/09/2024  SIN INFORMACION
# 1                     t             26/09/2024       26/03/2023
# 2                     t             26/09/2024       05/05/2024
# 3                     t             25/09/2024       22/09/2024
# 4                     t             25/09/2024       16/08/2023
# ...                 ...                    ...              ...
# 26577                 t             25/09/2024  SIN INFORMACION
# 26578                 t             25/09/2024  SIN INFORMACION
# 26579                 t             25/09/2024  SIN INFORMACION
# 26580                 t             25/09/2024  SIN INFORMACION
# 26581                 t             25/09/2024  SIN INFORMACION
#
#                license  instant_bookable
# 0      SIN INFORMACION                 f
# 1      SIN INFORMACION                 f
# 2      SIN INFORMACION                 f
# 3      SIN INFORMACION                 f
# 4      SIN INFORMACION                 f
# ...                ...               ...
# 26577  SIN INFORMACION                 t
# 26578  SIN INFORMACION                 t
# 26579  SIN INFORMACION                 t
# 26580  SIN INFORMACION                 t
# 26581  SIN INFORMACION                 t
#
# [26582 rows x 50 columns]

# %%
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_is_superhost              0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# bathrooms_text                 0
# amenities                      0
# calendar_updated               0
# has_availability               0
# calendar_last_scraped          0
# last_review                    0
# license                        0
# instant_bookable               0
# dtype: int64

# %%
#Convertimos dataframe a csv

Datos_limpios.to_csv("México sin atipicos.csv")
