# %% [markdown]
# **Actividad 4.2 Valores Atípicos**

# %% [markdown]
# Importar librerias

# %%
# Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Cargar archivo del pais Naples

# %%
# Carga desde un archivo .scv sin indice
data = pd.read_csv('Naples_sin_nulos.csv')

# %%
data = data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#                  id last_scraped  \
# 0      3.046600e+04   17/09/2024
# 1      3.053600e+04   17/09/2024
# 2      6.341300e+04   17/09/2024
# 3      7.436400e+04   17/09/2024
# 4      7.699300e+04   17/09/2024
# ...             ...          ...
# 11022  1.240000e+18   17/09/2024
# 11023  1.240000e+18   17/09/2024
# 11024  1.240000e+18   17/09/2024
# 11025  1.250000e+18   17/09/2024
# 11026  1.250000e+18   17/09/2024
#
#                                                     name  \
# 0                   Naturists rooms in the heart of city
# 1                            cosy room to let  in naples
# 2                     Charming Room on Riviera di Chiaia
# 3        Cozy place in a princely Palace inside Old Town
# 4      Central Cebollitas B&B, spacious private ensuite.
# ...                                                  ...
# 11022                           Domus Parthenope Confort
# 11023                                      Casetta lulÃ¹
# 11024  TATTINELLAâs, hidden gem in the heart of Naples
# 11025                        Irmaâs House casa vacanze
# 11026                                    La piccola Arca
#
#                                              description  \
# 0      Right in the heart of Napoli  you can walk any...
# 1      Oriental decorated apartment with wonderful te...
# 2      Centrally located and at walking distance to t...
# 3      A really cozy studio (24 square meters) in a p...
# 4      A bright, sunny home in vomero area (on a hill...
# ...                                                  ...
# 11022  Relax in this peaceful and centrally-located p...
# 11023  Your family will be close to everything when y...
# 11024  Located in the beating heart of the city, our ...
# 11025  Relax with the whole family at this peaceful a...
# 11026  This special place is close to everything, mak...
#
#                                    neighborhood_overview  \
# 0      close to 2 underground lines, next to bus stop...
# 1      Centrally located,close to public transport, i...
# 2      The house is located in a lively and popular n...
# 3      The flat is in the OLD TOWN od Napoli with 2 m...
# 4      La casa di Cebollitas si trova a Napoli, Campa...
# ...                                                  ...
# 11022                                    Sin especificar
# 11023                                    Sin especificar
# 11024                                    Sin especificar
# 11025                                    Sin especificar
# 11026                                    Sin especificar
#
#                                              picture_url   host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...        Gigi
# 1      https://a0.muscache.com/pictures/171280/92fe69...        Gigi
# 2      https://a0.muscache.com/pictures/389538/99361e...       Paola
# 3      https://a0.muscache.com/pictures/c8a48f3d-1be3...      Davide
# 4      https://a0.muscache.com/pictures/miso/Hosting-...  Cebollitas
# ...                                                  ...         ...
# 11022  https://a0.muscache.com/pictures/hosting/Hosti...   Gianpiero
# 11023  https://a0.muscache.com/pictures/hosting/Hosti...       Luisa
# 11024  https://a0.muscache.com/pictures/miso/Hosting-...      Simona
# 11025  https://a0.muscache.com/pictures/hosting/Hosti...        Jari
# 11026  https://a0.muscache.com/pictures/hosting/Hosti...    Giovanni
#
#        host_since                                         host_about  \
# 0      11/04/2014  Innamorato della bellezza quindi la cerco in o...
# 1      11/04/2014  Innamorato della bellezza quindi la cerco in o...
# 2      04/12/2010        Le Stanze dei Pollano - this is our website
# 3      17/11/2010          Architecture, art, archeology, good food.
# 4      26/02/2011  Cebollitas is a homely modern b&b  situated in...
# ...           ...                                                ...
# 11022  30/10/2023                                    Sin especificar
# 11023  11/09/2024                                    Sin especificar
# 11024  28/12/2023  Ciao, noi siamo Simona&Valentina, sorelle molt...
# 11025  09/11/2014                                    Sin especificar
# 11026  24/11/2023                                    Sin especificar
#
#        host_response_time  ...  review_scores_rating  review_scores_accuracy  \
# 0         Sin especificar  ...                  4.67                    4.67
# 1         Sin especificar  ...                  4.74                    4.83
# 2      within a few hours  ...                  4.65                    4.78
# 3          within an hour  ...                  4.89                    4.88
# 4          within an hour  ...                  4.97                    4.90
# ...                   ...  ...                   ...                     ...
# 11022      within an hour  ...                  4.70                    4.90
# 11023     Sin especificar  ...                  4.70                    4.90
# 11024      within an hour  ...                  4.70                    4.90
# 11025     Sin especificar  ...                  4.70                    4.90
# 11026      within an hour  ...                  4.70                    4.90
#
#       review_scores_cleanliness  review_scores_checkin  \
# 0                          5.00                   4.67
# 1                          4.72                   4.83
# 2                          4.50                   4.92
# 3                          4.92                   4.96
# 4                          4.94                   4.90
# ...                         ...                    ...
# 11022                      4.90                   4.90
# 11023                      4.90                   4.90
# 11024                      4.90                   4.90
# 11025                      4.90                   4.90
# 11026                      4.90                   4.90
#
#        review_scores_communication review_scores_location review_scores_value  \
# 0                             5.00                   5.00                4.67
# 1                             4.78                   4.44                4.56
# 2                             4.82                   4.73                4.68
# 3                             4.97                   4.84                4.89
# 4                             4.98                   4.92                4.94
# ...                            ...                    ...                 ...
# 11022                         5.00                   4.80                4.80
# 11023                         5.00                   4.80                4.80
# 11024                         5.00                   4.80                4.80
# 11025                         5.00                   4.80                4.80
# 11026                         5.00                   4.80                4.80
#
#                   license instant_bookable reviews_per_month
# 0         Sin especificar                f              0.18
# 1         Sin especificar                f              0.11
# 2         Sin especificar                f              0.93
# 3         Sin especificar                f              1.68
# 4         Sin especificar                f              0.52
# ...                   ...              ...               ...
# 11022     Sin especificar                t              0.90
# 11023     Sin especificar                f              0.90
# 11024  IT063049C2T96VI9PI                f              0.90
# 11025     Sin especificar                f              0.90
# 11026     Sin especificar                t              0.90
#
# [11027 rows x 50 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11027 entries, 0 to 11026
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           11027 non-null  float64
#  1   last_scraped                 11027 non-null  object
#  2   name                         11027 non-null  object
#  3   description                  11027 non-null  object
#  4   neighborhood_overview        11027 non-null  object
#  5   picture_url                  11027 non-null  object
#  6   host_name                    11027 non-null  object
#  7   host_since                   11027 non-null  object
#  8   host_about                   11027 non-null  object
#  9   host_response_time           11027 non-null  object
#  10  host_response_rate           11027 non-null  float64
#  11  host_acceptance_rate         11027 non-null  float64
#  12  host_is_superhost            11027 non-null  object
#  13  host_listings_count          11027 non-null  int64
#  14  host_total_listings_count    11027 non-null  int64
#  15  host_verifications           11027 non-null  object
#  16  host_has_profile_pic         11027 non-null  object
#  17  host_identity_verified       11027 non-null  object
#  18  neighbourhood                11027 non-null  object
#  19  property_type                11027 non-null  object
#  20  room_type                    11027 non-null  object
#  21  accommodates                 11027 non-null  int64
#  22  bathrooms                    11027 non-null  float64
#  23  bathrooms_text               11027 non-null  object
#  24  bedrooms                     11027 non-null  float64
#  25  beds                         11027 non-null  float64
#  26  amenities                    11027 non-null  object
#  27  price                        11027 non-null  float64
#  28  minimum_nights               11027 non-null  int64
#  29  maximum_nights               11027 non-null  int64
#  30  calendar_updated             11027 non-null  object
#  31  has_availability             11027 non-null  object
#  32  availability_30              11027 non-null  int64
#  33  availability_60              11027 non-null  int64
#  34  availability_365             11027 non-null  int64
#  35  calendar_last_scraped        11027 non-null  object
#  36  number_of_reviews            11027 non-null  int64
#  37  number_of_reviews_ltm        11027 non-null  int64
#  38  number_of_reviews_l30d       11027 non-null  int64
#  39  last_review                  11027 non-null  object
#  40  review_scores_rating         11027 non-null  float64
#  41  review_scores_accuracy       11027 non-null  float64
#  42  review_scores_cleanliness    11027 non-null  float64
#  43  review_scores_checkin        11027 non-null  float64
#  44  review_scores_communication  11027 non-null  float64
#  45  review_scores_location       11027 non-null  float64
#  46  review_scores_value          11027 non-null  float64
#  47  license                      11027 non-null  object
#  48  instant_bookable             11027 non-null  object
#  49  reviews_per_month            11027 non-null  float64
# dtypes: float64(15), int64(11), object(24)
# memory usage: 4.2+ MB

# %%
# Corroborar valores nulos
valores_nulos = data.isnull().sum()
valores_nulos
# Out:
# id                             0
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms                      0
# bathrooms_text                 0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# calendar_updated               0
# has_availability               0
# availability_30                0
# availability_60                0
# availability_365               0
# calendar_last_scraped          0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# last_review                    0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# license                        0
# instant_bookable               0
# reviews_per_month              0
# dtype: int64

# %%
cuantitativas = data.iloc[ : , [0, 10, 11, 13, 14, 21, 22, 24, 25, 27, 28, 29, 32, 33, 34, 36, 37, 38, 40, 41, 42, 43, 44, 45, 46, 49]]
cualitativas = data.iloc[:, [1, 2, 3, 4, 5, 6, 7, 8, 9, 12, 15, 16, 17, 18, 19, 20, 23, 26, 30, 31, 35, 39, 47, 48]]

# %%
cualitativas
# Out:
#       last_scraped                                               name  \
# 0       17/09/2024               Naturists rooms in the heart of city
# 1       17/09/2024                        cosy room to let  in naples
# 2       17/09/2024                 Charming Room on Riviera di Chiaia
# 3       17/09/2024    Cozy place in a princely Palace inside Old Town
# 4       17/09/2024  Central Cebollitas B&B, spacious private ensuite.
# ...            ...                                                ...
# 11022   17/09/2024                           Domus Parthenope Confort
# 11023   17/09/2024                                      Casetta lulÃ¹
# 11024   17/09/2024  TATTINELLAâs, hidden gem in the heart of Naples
# 11025   17/09/2024                        Irmaâs House casa vacanze
# 11026   17/09/2024                                    La piccola Arca
#
#                                              description  \
# 0      Right in the heart of Napoli  you can walk any...
# 1      Oriental decorated apartment with wonderful te...
# 2      Centrally located and at walking distance to t...
# 3      A really cozy studio (24 square meters) in a p...
# 4      A bright, sunny home in vomero area (on a hill...
# ...                                                  ...
# 11022  Relax in this peaceful and centrally-located p...
# 11023  Your family will be close to everything when y...
# 11024  Located in the beating heart of the city, our ...
# 11025  Relax with the whole family at this peaceful a...
# 11026  This special place is close to everything, mak...
#
#                                    neighborhood_overview  \
# 0      close to 2 underground lines, next to bus stop...
# 1      Centrally located,close to public transport, i...
# 2      The house is located in a lively and popular n...
# 3      The flat is in the OLD TOWN od Napoli with 2 m...
# 4      La casa di Cebollitas si trova a Napoli, Campa...
# ...                                                  ...
# 11022                                    Sin especificar
# 11023                                    Sin especificar
# 11024                                    Sin especificar
# 11025                                    Sin especificar
# 11026                                    Sin especificar
#
#                                              picture_url   host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...        Gigi
# 1      https://a0.muscache.com/pictures/171280/92fe69...        Gigi
# 2      https://a0.muscache.com/pictures/389538/99361e...       Paola
# 3      https://a0.muscache.com/pictures/c8a48f3d-1be3...      Davide
# 4      https://a0.muscache.com/pictures/miso/Hosting-...  Cebollitas
# ...                                                  ...         ...
# 11022  https://a0.muscache.com/pictures/hosting/Hosti...   Gianpiero
# 11023  https://a0.muscache.com/pictures/hosting/Hosti...       Luisa
# 11024  https://a0.muscache.com/pictures/miso/Hosting-...      Simona
# 11025  https://a0.muscache.com/pictures/hosting/Hosti...        Jari
# 11026  https://a0.muscache.com/pictures/hosting/Hosti...    Giovanni
#
#        host_since                                         host_about  \
# 0      11/04/2014  Innamorato della bellezza quindi la cerco in o...
# 1      11/04/2014  Innamorato della bellezza quindi la cerco in o...
# 2      04/12/2010        Le Stanze dei Pollano - this is our website
# 3      17/11/2010          Architecture, art, archeology, good food.
# 4      26/02/2011  Cebollitas is a homely modern b&b  situated in...
# ...           ...                                                ...
# 11022  30/10/2023                                    Sin especificar
# 11023  11/09/2024                                    Sin especificar
# 11024  28/12/2023  Ciao, noi siamo Simona&Valentina, sorelle molt...
# 11025  09/11/2014                                    Sin especificar
# 11026  24/11/2023                                    Sin especificar
#
#        host_response_time host_is_superhost  ...  \
# 0         Sin especificar                 f  ...
# 1         Sin especificar                 f  ...
# 2      within a few hours                 f  ...
# 3          within an hour   Sin especificar  ...
# 4          within an hour                 t  ...
# ...                   ...               ...  ...
# 11022      within an hour                 f  ...
# 11023     Sin especificar                 f  ...
# 11024      within an hour                 f  ...
# 11025     Sin especificar                 f  ...
# 11026      within an hour                 f  ...
#
#                            property_type        room_type    bathrooms_text  \
# 0      Private room in bed and breakfast     Private room     1 shared bath
# 1                  Private room in condo     Private room  Shared half-bath
# 2                     Entire rental unit  Entire home/apt            1 bath
# 3                     Entire rental unit  Entire home/apt            1 bath
# 4                  Private room in condo     Private room    1 private bath
# ...                                  ...              ...               ...
# 11022               Entire vacation home  Entire home/apt           2 baths
# 11023                        Entire home  Entire home/apt            1 bath
# 11024                 Entire rental unit  Entire home/apt            1 bath
# 11025                 Entire rental unit  Entire home/apt           2 baths
# 11026                        Entire home  Entire home/apt            1 bath
#
#                                                amenities calendar_updated  \
# 0      ["City skyline view", "Heating", "TV with stan...  Sin especificar
# 1      ["Hot water", "TV", "Lock on bedroom door", "H...  Sin especificar
# 2      ["TV", "Heating", "Essentials", "Shampoo", "Ki...  Sin especificar
# 3      ["Smoke alarm", "Hot water", "City skyline vie...  Sin especificar
# 4      ["Hot water", "Essentials", "Elevator", "Coffe...  Sin especificar
# ...                                                  ...              ...
# 11022  ["Hot water", "Exterior security cameras on pr...  Sin especificar
# 11023  ["Smoke alarm", "TV", "Kitchen", "Fire extingu...  Sin especificar
# 11024  ["Hot water", "Exterior security cameras on pr...  Sin especificar
# 11025  ["Hot water", "Exterior security cameras on pr...  Sin especificar
# 11026  ["Air conditioning", "TV", "Dedicated workspace"]  Sin especificar
#
#       has_availability calendar_last_scraped      last_review  \
# 0                    t            17/09/2024       17/09/2023
# 1                    t            17/09/2024       10/10/2022
# 2                    t            17/09/2024       22/08/2024
# 3                    t            17/09/2024       29/08/2024
# 4                    t            17/09/2024       31/08/2024
# ...                ...                   ...              ...
# 11022                t            17/09/2024  Sin especificar
# 11023                t            17/09/2024  Sin especificar
# 11024                t            17/09/2024  Sin especificar
# 11025                t            17/09/2024  Sin especificar
# 11026                t            17/09/2024  Sin especificar
#
#                   license instant_bookable
# 0         Sin especificar                f
# 1         Sin especificar                f
# 2         Sin especificar                f
# 3         Sin especificar                f
# 4         Sin especificar                f
# ...                   ...              ...
# 11022     Sin especificar                t
# 11023     Sin especificar                f
# 11024  IT063049C2T96VI9PI                f
# 11025     Sin especificar                f
# 11026     Sin especificar                t
#
# [11027 rows x 24 columns]

# %%
# Relaizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize= (15,8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["reviews_per_month"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["review_scores_value"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["review_scores_location"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["review_scores_communication"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["review_scores_checkin"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["review_scores_cleanliness"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["review_scores_accuracy"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["review_scores_rating"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["number_of_reviews"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["number_of_reviews_ltm"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["number_of_reviews"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["availability_365"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["availability_60"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["availability_30"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["maximum_nights"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["minimum_nights"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["price"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["beds"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["bedrooms"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["bathrooms"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["accommodates"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["host_total_listings_count"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["host_listings_count"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["host_acceptance_rate"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %%
# Para Analizar una en especifico
fig = plt.figure(figsize= (15,8))
cuantitativas["id"].plot(kind='box', vert=False)
plt.title("Valores Atípicos del DataFrame")
plt.show() #dibujamos el diagrama

# %% [markdown]
# **Procedimiento "Desviación estándar**

# %%
y = cuantitativas
Limite_Superior = y.mean() + 3*y.std()
Limite_Inferior = y.mean() - 3*y.std()

print("Limite superir permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superir permitido id                             2.071878e+18
# host_response_rate             1.223908e+00
# host_acceptance_rate           1.420076e+00
# host_listings_count            1.843894e+02
# host_total_listings_count      2.930017e+02
# accommodates                   9.898679e+00
# bathrooms                      2.862001e+00
# bedrooms                       3.683063e+00
# beds                           7.007919e+00
# price                          8.430184e+02
# minimum_nights                 2.428845e+01
# maximum_nights                 1.596765e+03
# availability_30                4.295272e+01
# availability_60                8.898892e+01
# availability_365               5.716947e+02
# number_of_reviews              2.596093e+02
# number_of_reviews_ltm          6.228352e+01
# number_of_reviews_l30d         6.199252e+00
# review_scores_rating           5.791983e+00
# review_scores_accuracy         5.813512e+00
# review_scores_cleanliness      5.827308e+00
# review_scores_checkin          5.778512e+00
# review_scores_communication    5.806917e+00
# review_scores_location         5.812112e+00
# review_scores_value            5.854603e+00
# reviews_per_month              5.822936e+00
# dtype: float64
# Limite inferior permitido id                            -8.720826e+17
# host_response_rate             7.409530e-01
# host_acceptance_rate           4.198711e-01
# host_listings_count           -1.554537e+02
# host_total_listings_count     -2.545880e+02
# accommodates                  -2.384033e+00
# bathrooms                     -4.287373e-01
# bedrooms                      -9.475225e-01
# beds                          -2.575634e+00
# price                         -6.077424e+02
# minimum_nights                -2.028972e+01
# maximum_nights                -8.209341e+02
# availability_30               -1.552223e+01
# availability_60               -2.035357e+01
# availability_365              -1.314519e+02
# number_of_reviews             -1.848026e+02
# number_of_reviews_ltm         -4.190046e+01
# number_of_reviews_l30d        -4.346527e+00
# review_scores_rating           3.645617e+00
# review_scores_accuracy         3.775926e+00
# review_scores_cleanliness      3.751606e+00
# review_scores_checkin          3.871402e+00
# review_scores_communication    3.941695e+00
# review_scores_location         3.609049e+00
# review_scores_value            3.539586e+00
# reviews_per_month             -3.097698e+00
# dtype: float64

# %%
# Obtenemos datos y los outliners se conviertan en nulos en el DataFrame
data1 = cuantitativas[(y <= Limite_Superior) & (y >= Limite_Inferior)]
data1
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.046600e+04                1.00                  0.50
# 1      3.053600e+04                1.00                  0.50
# 2      6.341300e+04                1.00                  1.00
# 3      7.436400e+04                1.00                  1.00
# 4      7.699300e+04                1.00                  0.98
# ...             ...                 ...                   ...
# 11022  1.240000e+18                1.00                  1.00
# 11023  1.240000e+18                1.00                  0.90
# 11024  1.240000e+18                1.00                  0.90
# 11025  1.250000e+18                1.00                  0.90
# 11026  1.250000e+18                0.75                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      8.0                       11.0           2.0
# 1                      8.0                       11.0           1.0
# 2                      1.0                        2.0           2.0
# 3                     13.0                       13.0           2.0
# 4                      4.0                        4.0           4.0
# ...                    ...                        ...           ...
# 11022                  2.0                        2.0           4.0
# 11023                  1.0                        2.0           4.0
# 11024                  1.0                        1.0           6.0
# 11025                  1.0                        1.0           4.0
# 11026                  1.0                        1.0           2.0
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0   71.0  ...                    0.0
# 1            0.5       1.0   1.0   76.0  ...                    0.0
# 2            1.0       1.0   1.0   68.0  ...                   21.0
# 3            1.0       1.0   1.0   58.0  ...                   29.0
# 4            1.0       1.0   2.0   60.0  ...                   31.0
# ...          ...       ...   ...    ...  ...                    ...
# 11022        2.0       2.0   2.0  100.0  ...                    0.0
# 11023        1.0       1.0   1.0  100.0  ...                    0.0
# 11024        1.0       2.0   3.0   83.0  ...                    0.0
# 11025        2.0       3.0   2.0   59.0  ...                    0.0
# 11026        1.0       1.0   1.0   18.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.67                    4.67
# 1                         0.0                  4.74                    4.83
# 2                         1.0                  4.65                    4.78
# 3                         2.0                  4.89                    4.88
# 4                         3.0                  4.97                    4.90
# ...                       ...                   ...                     ...
# 11022                     0.0                  4.70                    4.90
# 11023                     0.0                  4.70                    4.90
# 11024                     0.0                  4.70                    4.90
# 11025                     0.0                  4.70                    4.90
# 11026                     0.0                  4.70                    4.90
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           5.00                   4.67
# 1                           4.72                   4.83
# 2                           4.50                   4.92
# 3                           4.92                   4.96
# 4                           4.94                   4.90
# ...                          ...                    ...
# 11022                       4.90                   4.90
# 11023                       4.90                   4.90
# 11024                       4.90                   4.90
# 11025                       4.90                   4.90
# 11026                       4.90                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             5.00                    5.00
# 1                             4.78                    4.44
# 2                             4.82                    4.73
# 3                             4.97                    4.84
# 4                             4.98                    4.92
# ...                            ...                     ...
# 11022                         5.00                    4.80
# 11023                         5.00                    4.80
# 11024                         5.00                    4.80
# 11025                         5.00                    4.80
# 11026                         5.00                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.67               0.18
# 1                     4.56               0.11
# 2                     4.68               0.93
# 3                     4.89               1.68
# 4                     4.94               0.52
# ...                    ...                ...
# 11022                 4.80               0.90
# 11023                 4.80               0.90
# 11024                 4.80               0.90
# 11025                 4.80               0.90
# 11026                 4.80               0.90
#
# [11027 rows x 26 columns]

# %%
# Corroborar valores nulos
valores_nulos = data1.isnull().sum()
valores_nulos
# Out:
# id                               0
# host_response_rate             237
# host_acceptance_rate           412
# host_listings_count            202
# host_total_listings_count       57
# accommodates                   226
# bathrooms                      297
# bedrooms                       197
# beds                           132
# price                           39
# minimum_nights                  55
# maximum_nights                   0
# availability_30                  0
# availability_60                  0
# availability_365                 0
# number_of_reviews              287
# number_of_reviews_ltm          255
# number_of_reviews_l30d         207
# review_scores_rating           168
# review_scores_accuracy         192
# review_scores_cleanliness      195
# review_scores_checkin          162
# review_scores_communication    158
# review_scores_location         204
# review_scores_value            228
# reviews_per_month              229
# dtype: int64

# %%
# Remplazamos valores atipicos (nulos) del dataframe con "mean"
# Realizamos una copia del dataframe

data_clean = data1.copy()
data_clean = data_clean.fillna(round(data1.mean(),1))
data_clean
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.046600e+04                1.00                  0.50
# 1      3.053600e+04                1.00                  0.50
# 2      6.341300e+04                1.00                  1.00
# 3      7.436400e+04                1.00                  1.00
# 4      7.699300e+04                1.00                  0.98
# ...             ...                 ...                   ...
# 11022  1.240000e+18                1.00                  1.00
# 11023  1.240000e+18                1.00                  0.90
# 11024  1.240000e+18                1.00                  0.90
# 11025  1.250000e+18                1.00                  0.90
# 11026  1.250000e+18                0.75                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      8.0                       11.0           2.0
# 1                      8.0                       11.0           1.0
# 2                      1.0                        2.0           2.0
# 3                     13.0                       13.0           2.0
# 4                      4.0                        4.0           4.0
# ...                    ...                        ...           ...
# 11022                  2.0                        2.0           4.0
# 11023                  1.0                        2.0           4.0
# 11024                  1.0                        1.0           6.0
# 11025                  1.0                        1.0           4.0
# 11026                  1.0                        1.0           2.0
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0   71.0  ...                    0.0
# 1            0.5       1.0   1.0   76.0  ...                    0.0
# 2            1.0       1.0   1.0   68.0  ...                   21.0
# 3            1.0       1.0   1.0   58.0  ...                   29.0
# 4            1.0       1.0   2.0   60.0  ...                   31.0
# ...          ...       ...   ...    ...  ...                    ...
# 11022        2.0       2.0   2.0  100.0  ...                    0.0
# 11023        1.0       1.0   1.0  100.0  ...                    0.0
# 11024        1.0       2.0   3.0   83.0  ...                    0.0
# 11025        2.0       3.0   2.0   59.0  ...                    0.0
# 11026        1.0       1.0   1.0   18.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.67                    4.67
# 1                         0.0                  4.74                    4.83
# 2                         1.0                  4.65                    4.78
# 3                         2.0                  4.89                    4.88
# 4                         3.0                  4.97                    4.90
# ...                       ...                   ...                     ...
# 11022                     0.0                  4.70                    4.90
# 11023                     0.0                  4.70                    4.90
# 11024                     0.0                  4.70                    4.90
# 11025                     0.0                  4.70                    4.90
# 11026                     0.0                  4.70                    4.90
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           5.00                   4.67
# 1                           4.72                   4.83
# 2                           4.50                   4.92
# 3                           4.92                   4.96
# 4                           4.94                   4.90
# ...                          ...                    ...
# 11022                       4.90                   4.90
# 11023                       4.90                   4.90
# 11024                       4.90                   4.90
# 11025                       4.90                   4.90
# 11026                       4.90                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             5.00                    5.00
# 1                             4.78                    4.44
# 2                             4.82                    4.73
# 3                             4.97                    4.84
# 4                             4.98                    4.92
# ...                            ...                     ...
# 11022                         5.00                    4.80
# 11023                         5.00                    4.80
# 11024                         5.00                    4.80
# 11025                         5.00                    4.80
# 11026                         5.00                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.67               0.18
# 1                     4.56               0.11
# 2                     4.68               0.93
# 3                     4.89               1.68
# 4                     4.94               0.52
# ...                    ...                ...
# 11022                 4.80               0.90
# 11023                 4.80               0.90
# 11024                 4.80               0.90
# 11025                 4.80               0.90
# 11026                 4.80               0.90
#
# [11027 rows x 26 columns]

# %%
# Corroborar valores nulos
valores_nulos = data_clean.isnull().sum()
valores_nulos
# Out:
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %% [markdown]
# **Procedimiento "Cuantiles" para sustituir outliers en dataframe**

# %%
# Método aplicando Cuartiles. Encontrar cuartiles 0.25 y 0.75 
y = cuantitativas

percentile25 = y.quantile(0.25) # Q1
percentile75 = y.quantile(0.75) # Q3
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr

print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido id                             2.600000e+18
# host_response_rate             1.000000e+00
# host_acceptance_rate           1.150000e+00
# host_listings_count            1.100000e+01
# host_total_listings_count      1.350000e+01
# accommodates                   7.000000e+00
# bathrooms                      1.000000e+00
# bedrooms                       3.500000e+00
# beds                           6.000000e+00
# price                          1.950000e+02
# minimum_nights                 3.500000e+00
# maximum_nights                 8.675000e+02
# availability_30                4.750000e+01
# availability_60                9.200000e+01
# availability_365               6.605000e+02
# number_of_reviews              9.100000e+01
# number_of_reviews_ltm          3.250000e+01
# number_of_reviews_l30d         2.500000e+00
# review_scores_rating           5.300000e+00
# review_scores_accuracy         5.245000e+00
# review_scores_cleanliness      5.350000e+00
# review_scores_checkin          5.245000e+00
# review_scores_communication    5.180000e+00
# review_scores_location         5.310000e+00
# review_scores_value            5.210000e+00
# reviews_per_month              3.645000e+00
# dtype: float64
# Limite inferior permitido id                            -1.560000e+18
# host_response_rate             1.000000e+00
# host_acceptance_rate           7.500000e-01
# host_listings_count           -5.000000e+00
# host_total_listings_count     -6.500000e+00
# accommodates                  -1.000000e+00
# bathrooms                      1.000000e+00
# bedrooms                      -5.000000e-01
# beds                          -2.000000e+00
# price                         -5.000000e+00
# minimum_nights                -5.000000e-01
# maximum_nights                -4.725000e+02
# availability_30               -2.050000e+01
# availability_60               -2.000000e+01
# availability_365              -2.155000e+02
# number_of_reviews             -5.300000e+01
# number_of_reviews_ltm         -1.950000e+01
# number_of_reviews_l30d        -1.500000e+00
# review_scores_rating           4.340000e+00
# review_scores_accuracy         4.485000e+00
# review_scores_cleanliness      4.390000e+00
# review_scores_checkin          4.565000e+00
# review_scores_communication    4.700000e+00
# review_scores_location         4.270000e+00
# review_scores_value            4.330000e+00
# reviews_per_month             -1.515000e+00
# dtype: float64

# %%
# Obtenemos datos limpios del dataframe
data1_iqr = cuantitativas [(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
data1_iqr
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.046600e+04                 1.0                   NaN
# 1      3.053600e+04                 1.0                   NaN
# 2      6.341300e+04                 1.0                  1.00
# 3      7.436400e+04                 1.0                  1.00
# 4      7.699300e+04                 1.0                  0.98
# ...             ...                 ...                   ...
# 11022  1.240000e+18                 1.0                  1.00
# 11023  1.240000e+18                 1.0                  0.90
# 11024  1.240000e+18                 1.0                  0.90
# 11025  1.250000e+18                 1.0                  0.90
# 11026  1.250000e+18                 NaN                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      8.0                       11.0           2.0
# 1                      8.0                       11.0           1.0
# 2                      1.0                        2.0           2.0
# 3                      NaN                       13.0           2.0
# 4                      4.0                        4.0           4.0
# ...                    ...                        ...           ...
# 11022                  2.0                        2.0           4.0
# 11023                  1.0                        2.0           4.0
# 11024                  1.0                        1.0           6.0
# 11025                  1.0                        1.0           4.0
# 11026                  1.0                        1.0           2.0
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0   71.0  ...                    0.0
# 1            NaN       1.0   1.0   76.0  ...                    0.0
# 2            1.0       1.0   1.0   68.0  ...                   21.0
# 3            1.0       1.0   1.0   58.0  ...                   29.0
# 4            1.0       1.0   2.0   60.0  ...                   31.0
# ...          ...       ...   ...    ...  ...                    ...
# 11022        NaN       2.0   2.0  100.0  ...                    0.0
# 11023        1.0       1.0   1.0  100.0  ...                    0.0
# 11024        1.0       2.0   3.0   83.0  ...                    0.0
# 11025        NaN       3.0   2.0   59.0  ...                    0.0
# 11026        1.0       1.0   1.0   18.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.67                    4.67
# 1                         0.0                  4.74                    4.83
# 2                         1.0                  4.65                    4.78
# 3                         2.0                  4.89                    4.88
# 4                         NaN                  4.97                    4.90
# ...                       ...                   ...                     ...
# 11022                     0.0                  4.70                    4.90
# 11023                     0.0                  4.70                    4.90
# 11024                     0.0                  4.70                    4.90
# 11025                     0.0                  4.70                    4.90
# 11026                     0.0                  4.70                    4.90
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           5.00                   4.67
# 1                           4.72                   4.83
# 2                           4.50                   4.92
# 3                           4.92                   4.96
# 4                           4.94                   4.90
# ...                          ...                    ...
# 11022                       4.90                   4.90
# 11023                       4.90                   4.90
# 11024                       4.90                   4.90
# 11025                       4.90                   4.90
# 11026                       4.90                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             5.00                    5.00
# 1                             4.78                    4.44
# 2                             4.82                    4.73
# 3                             4.97                    4.84
# 4                             4.98                    4.92
# ...                            ...                     ...
# 11022                         5.00                    4.80
# 11023                         5.00                    4.80
# 11024                         5.00                    4.80
# 11025                         5.00                    4.80
# 11026                         5.00                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.67               0.18
# 1                     4.56               0.11
# 2                     4.68               0.93
# 3                     4.89               1.68
# 4                     4.94               0.52
# ...                    ...                ...
# 11022                 4.80               0.90
# 11023                 4.80               0.90
# 11024                 4.80               0.90
# 11025                 4.80               0.90
# 11026                 4.80               0.90
#
# [11027 rows x 26 columns]

# %%
# Corroboramos datos limpios del DataFrame
valores_nulos = data1_iqr.isnull().sum()
valores_nulos
# Out:
# id                                0
# host_response_rate             1208
# host_acceptance_rate            996
# host_listings_count            1270
# host_total_listings_count      1250
# accommodates                    537
# bathrooms                      2710
# bedrooms                        197
# beds                            205
# price                           876
# minimum_nights                  344
# maximum_nights                 2237
# availability_30                   0
# availability_60                   0
# availability_365                  0
# number_of_reviews              1400
# number_of_reviews_ltm          1108
# number_of_reviews_l30d         1562
# review_scores_rating            904
# review_scores_accuracy          923
# review_scores_cleanliness       875
# review_scores_checkin          1025
# review_scores_communication    1268
# review_scores_location          992
# review_scores_value             985
# reviews_per_month               912
# dtype: int64

# %%
# Remplazamos valores atipicos (nulos del data con mean)
# Realizamos una copia del dataframe

data2_iqr = data1_iqr.copy()
data2_iqr = data1_iqr.fillna(round(data1_iqr.mean(),1))
data2_iqr
# Out:
#                  id  host_response_rate  host_acceptance_rate  \
# 0      3.046600e+04                 1.0                  1.00
# 1      3.053600e+04                 1.0                  1.00
# 2      6.341300e+04                 1.0                  1.00
# 3      7.436400e+04                 1.0                  1.00
# 4      7.699300e+04                 1.0                  0.98
# ...             ...                 ...                   ...
# 11022  1.240000e+18                 1.0                  1.00
# 11023  1.240000e+18                 1.0                  0.90
# 11024  1.240000e+18                 1.0                  0.90
# 11025  1.250000e+18                 1.0                  0.90
# 11026  1.250000e+18                 1.0                  0.98
#
#        host_listings_count  host_total_listings_count  accommodates  \
# 0                      8.0                       11.0           2.0
# 1                      8.0                       11.0           1.0
# 2                      1.0                        2.0           2.0
# 3                      3.0                       13.0           2.0
# 4                      4.0                        4.0           4.0
# ...                    ...                        ...           ...
# 11022                  2.0                        2.0           4.0
# 11023                  1.0                        2.0           4.0
# 11024                  1.0                        1.0           6.0
# 11025                  1.0                        1.0           4.0
# 11026                  1.0                        1.0           2.0
#
#        bathrooms  bedrooms  beds  price  ...  number_of_reviews_ltm  \
# 0            1.0       1.0   1.0   71.0  ...                    0.0
# 1            1.0       1.0   1.0   76.0  ...                    0.0
# 2            1.0       1.0   1.0   68.0  ...                   21.0
# 3            1.0       1.0   1.0   58.0  ...                   29.0
# 4            1.0       1.0   2.0   60.0  ...                   31.0
# ...          ...       ...   ...    ...  ...                    ...
# 11022        1.0       2.0   2.0  100.0  ...                    0.0
# 11023        1.0       1.0   1.0  100.0  ...                    0.0
# 11024        1.0       2.0   3.0   83.0  ...                    0.0
# 11025        1.0       3.0   2.0   59.0  ...                    0.0
# 11026        1.0       1.0   1.0   18.0  ...                    0.0
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                         0.0                  4.67                    4.67
# 1                         0.0                  4.74                    4.83
# 2                         1.0                  4.65                    4.78
# 3                         2.0                  4.89                    4.88
# 4                         0.3                  4.97                    4.90
# ...                       ...                   ...                     ...
# 11022                     0.0                  4.70                    4.90
# 11023                     0.0                  4.70                    4.90
# 11024                     0.0                  4.70                    4.90
# 11025                     0.0                  4.70                    4.90
# 11026                     0.0                  4.70                    4.90
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           5.00                   4.67
# 1                           4.72                   4.83
# 2                           4.50                   4.92
# 3                           4.92                   4.96
# 4                           4.94                   4.90
# ...                          ...                    ...
# 11022                       4.90                   4.90
# 11023                       4.90                   4.90
# 11024                       4.90                   4.90
# 11025                       4.90                   4.90
# 11026                       4.90                   4.90
#
#        review_scores_communication  review_scores_location  \
# 0                             5.00                    5.00
# 1                             4.78                    4.44
# 2                             4.82                    4.73
# 3                             4.97                    4.84
# 4                             4.98                    4.92
# ...                            ...                     ...
# 11022                         5.00                    4.80
# 11023                         5.00                    4.80
# 11024                         5.00                    4.80
# 11025                         5.00                    4.80
# 11026                         5.00                    4.80
#
#        review_scores_value  reviews_per_month
# 0                     4.67               0.18
# 1                     4.56               0.11
# 2                     4.68               0.93
# 3                     4.89               1.68
# 4                     4.94               0.52
# ...                    ...                ...
# 11022                 4.80               0.90
# 11023                 4.80               0.90
# 11024                 4.80               0.90
# 11025                 4.80               0.90
# 11026                 4.80               0.90
#
# [11027 rows x 26 columns]

# %%
# Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
Datos_limpios = pd.concat([cualitativas, data2_iqr], axis=1)
Datos_limpios
# Out:
#       last_scraped                                               name  \
# 0       17/09/2024               Naturists rooms in the heart of city
# 1       17/09/2024                        cosy room to let  in naples
# 2       17/09/2024                 Charming Room on Riviera di Chiaia
# 3       17/09/2024    Cozy place in a princely Palace inside Old Town
# 4       17/09/2024  Central Cebollitas B&B, spacious private ensuite.
# ...            ...                                                ...
# 11022   17/09/2024                           Domus Parthenope Confort
# 11023   17/09/2024                                      Casetta lulÃ¹
# 11024   17/09/2024  TATTINELLAâs, hidden gem in the heart of Naples
# 11025   17/09/2024                        Irmaâs House casa vacanze
# 11026   17/09/2024                                    La piccola Arca
#
#                                              description  \
# 0      Right in the heart of Napoli  you can walk any...
# 1      Oriental decorated apartment with wonderful te...
# 2      Centrally located and at walking distance to t...
# 3      A really cozy studio (24 square meters) in a p...
# 4      A bright, sunny home in vomero area (on a hill...
# ...                                                  ...
# 11022  Relax in this peaceful and centrally-located p...
# 11023  Your family will be close to everything when y...
# 11024  Located in the beating heart of the city, our ...
# 11025  Relax with the whole family at this peaceful a...
# 11026  This special place is close to everything, mak...
#
#                                    neighborhood_overview  \
# 0      close to 2 underground lines, next to bus stop...
# 1      Centrally located,close to public transport, i...
# 2      The house is located in a lively and popular n...
# 3      The flat is in the OLD TOWN od Napoli with 2 m...
# 4      La casa di Cebollitas si trova a Napoli, Campa...
# ...                                                  ...
# 11022                                    Sin especificar
# 11023                                    Sin especificar
# 11024                                    Sin especificar
# 11025                                    Sin especificar
# 11026                                    Sin especificar
#
#                                              picture_url   host_name  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...        Gigi
# 1      https://a0.muscache.com/pictures/171280/92fe69...        Gigi
# 2      https://a0.muscache.com/pictures/389538/99361e...       Paola
# 3      https://a0.muscache.com/pictures/c8a48f3d-1be3...      Davide
# 4      https://a0.muscache.com/pictures/miso/Hosting-...  Cebollitas
# ...                                                  ...         ...
# 11022  https://a0.muscache.com/pictures/hosting/Hosti...   Gianpiero
# 11023  https://a0.muscache.com/pictures/hosting/Hosti...       Luisa
# 11024  https://a0.muscache.com/pictures/miso/Hosting-...      Simona
# 11025  https://a0.muscache.com/pictures/hosting/Hosti...        Jari
# 11026  https://a0.muscache.com/pictures/hosting/Hosti...    Giovanni
#
#        host_since                                         host_about  \
# 0      11/04/2014  Innamorato della bellezza quindi la cerco in o...
# 1      11/04/2014  Innamorato della bellezza quindi la cerco in o...
# 2      04/12/2010        Le Stanze dei Pollano - this is our website
# 3      17/11/2010          Architecture, art, archeology, good food.
# 4      26/02/2011  Cebollitas is a homely modern b&b  situated in...
# ...           ...                                                ...
# 11022  30/10/2023                                    Sin especificar
# 11023  11/09/2024                                    Sin especificar
# 11024  28/12/2023  Ciao, noi siamo Simona&Valentina, sorelle molt...
# 11025  09/11/2014                                    Sin especificar
# 11026  24/11/2023                                    Sin especificar
#
#        host_response_time host_is_superhost  ... number_of_reviews_ltm  \
# 0         Sin especificar                 f  ...                   0.0
# 1         Sin especificar                 f  ...                   0.0
# 2      within a few hours                 f  ...                  21.0
# 3          within an hour   Sin especificar  ...                  29.0
# 4          within an hour                 t  ...                  31.0
# ...                   ...               ...  ...                   ...
# 11022      within an hour                 f  ...                   0.0
# 11023     Sin especificar                 f  ...                   0.0
# 11024      within an hour                 f  ...                   0.0
# 11025     Sin especificar                 f  ...                   0.0
# 11026      within an hour                 f  ...                   0.0
#
#       number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 0                        0.0                 4.67                   4.67
# 1                        0.0                 4.74                   4.83
# 2                        1.0                 4.65                   4.78
# 3                        2.0                 4.89                   4.88
# 4                        0.3                 4.97                   4.90
# ...                      ...                  ...                    ...
# 11022                    0.0                 4.70                   4.90
# 11023                    0.0                 4.70                   4.90
# 11024                    0.0                 4.70                   4.90
# 11025                    0.0                 4.70                   4.90
# 11026                    0.0                 4.70                   4.90
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                          5.00                  4.67
# 1                          4.72                  4.83
# 2                          4.50                  4.92
# 3                          4.92                  4.96
# 4                          4.94                  4.90
# ...                         ...                   ...
# 11022                      4.90                  4.90
# 11023                      4.90                  4.90
# 11024                      4.90                  4.90
# 11025                      4.90                  4.90
# 11026                      4.90                  4.90
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            5.00                   5.00                4.67
# 1                            4.78                   4.44                4.56
# 2                            4.82                   4.73                4.68
# 3                            4.97                   4.84                4.89
# 4                            4.98                   4.92                4.94
# ...                           ...                    ...                 ...
# 11022                        5.00                   4.80                4.80
# 11023                        5.00                   4.80                4.80
# 11024                        5.00                   4.80                4.80
# 11025                        5.00                   4.80                4.80
# 11026                        5.00                   4.80                4.80
#
#       reviews_per_month
# 0                  0.18
# 1                  0.11
# 2                  0.93
# 3                  1.68
# 4                  0.52
# ...                 ...
# 11022              0.90
# 11023              0.90
# 11024              0.90
# 11025              0.90
# 11026              0.90
#
# [11027 rows x 50 columns]

# %%
# Corroboramos datos limpios del DataFrame
valores_nulos = Datos_limpios.isnull().sum()
valores_nulos
# Out:
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_is_superhost              0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# bathrooms_text                 0
# amenities                      0
# calendar_updated               0
# has_availability               0
# calendar_last_scraped          0
# last_review                    0
# license                        0
# instant_bookable               0
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
Datos_limpios.to_csv("Datos_limpios_Naples.cvs")
